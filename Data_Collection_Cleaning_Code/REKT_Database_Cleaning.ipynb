# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## REKT Database from DEFIYIELD

# %%
import pandas as pd             #pandas for using dataframe and reading csv file(s)
import json
import numpy as np              #numpy for vector operations and basic maths
import matplotlib.pyplot as plt #for plotting
# %matplotlib inline              
import seaborn as sns           #for making plots
import math                     #for basic math operations
import warnings
# from pandas.plotting import parallel_coordinates #for multivariate plots
warnings.filterwarnings('ignore') #ignore deprecation warnings

# %%
#importing data

open_REKTjson = open('../Data/REKT_Database_Python_API.json')
load_REKTjson = json.load(open_REKTjson)
REKT_df = pd.DataFrame(load_REKTjson)

REKT_df.head(5) # visualize first 5 instances of raw data
# Out:
#      id   project_name                                        description  \
# 0  3058  Terra Classic  <p><strong>Quick Summary</strong></p><p>A comp...
# 1  2762      Africrypt  <p><strong>Quick Summary</strong></p><p>Ameer ...
# 2  3264      Silk Road  <p><strong>Quick Summary</strong></p><p>Silk R...
# 3  2878      PlusToken  <p><strong>Quick Summary</strong></p><p>The pe...
# 4  3280        Genesis  <p><strong>Quick Summary</strong></p><p>Genesi...
#
#               name_categories  token_name  \
# 0                  Stablecoin  LUNC, USTC
# 1                        CeFi        None
# 2                       Other        None
# 3                        CeFi        None
# 4  Borrowing and Lending,CeFi        None
#
#                                   proof_archive_link technical_issue  \
# 0  https://twitter.com/OnChainWizard/status/15241...            None
# 1                                               None            None
# 2  https://archive.ph/FhvAa, https://archive.ph/v...            None
# 3                                               None            None
# 4  https://archive.ph/PyGbf, https://archive.ph/N...            None
#
#                                        token_address  \
# 0  0x7e43d25EaD96B1058f671F6690ea705BA2C7e5B9, 0x...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                      token_addresses  \
# 0  [{'address': '0xa47c8bf37f92abed4a126bda807a7b...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                          logo_link  ...  \
# 0  safe/files/scamDatabase/logo/62b31ccc0d07e.jpeg  ...
# 1   safe/files/scamDatabase/logo/61e049352a11a.png  ...
# 2   safe/files/scamDatabase/logo/636e4d3241822.jpg  ...
# 3   safe/files/scamDatabase/logo/62432b9d39213.png  ...
# 4   safe/files/scamDatabase/logo/637de4cb8793f.jpg  ...
#
#                            discord bug_bounty_program_link  \
# 0  https://twitter.com/terra_money                    None
# 1                             None                    None
# 2                             None                    None
# 3                             None                    None
# 4                             None                    None
#
#   bug_bounty_program_company audit_code_conf is_verified_source_code  \
# 0                       None             0.0                     0.0
# 1                       None             NaN                     0.0
# 2                       None             NaN                     0.0
# 3                       None             NaN                     0.0
# 4                       None             NaN                     0.0
#
#   is_public_team                      scam_type network  \
# 0            1.0    {'id': 19, 'type': 'Other'}      {}
# 1            1.0  {'id': 10, 'type': 'Rugpull'}      {}
# 2            1.0    {'id': 19, 'type': 'Other'}      {}
# 3            0.0  {'id': 10, 'type': 'Rugpull'}      {}
# 4            1.0    {'id': 18, 'type': 'Other'}      {}
#
#                                         scamNetworks  \
# 0  [{'networks_id': 1003, 'scam_database_id': 305...
# 1  [{'networks_id': 1666600003, 'scam_database_id...
# 2  [{'networks_id': 1666600003, 'scam_database_id...
# 3  [{'networks_id': 1666600003, 'scam_database_id...
# 4  [{'networks_id': 1666600003, 'scam_database_id...
#
#                                            auditedBy
# 0  [{'audit_link': 'safe/files/audit/pdf/CertiK_A...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
# [5 rows x 35 columns]

# %%
REKT_df.tail(5) # visualize last 5 instances of raw data
# Out:
#       id      project_name                                        description  \
# 3508  78      BoobsFinance                                               None
# 3509  77        Chad Token  <p>The contract owner could disable the transf...
# 3510  76  Generate Finance  <p><span data-sheets-userformat='{"2":15165,"3...
# 3511  72      Pill Finance  <p><span data-sheets-userformat='{"2":15165,"3...
# 3512  55     SoftdrinkSwap  <p>The team abandoned the project. The team st...
#
#        name_categories token_name proof_archive_link technical_issue  \
# 3508             Token      BOOBS               None            None
# 3509             Token       CHAD               None            None
# 3510  Yield Aggregator        GEN               None            None
# 3511    Exchange (DEX)      RED-P               None            None
# 3512    Exchange (DEX)  COLA SODA               None            None
#
#                                    token_address token_addresses  \
# 3508  0xf98f73350d083005079b6c3cda9c99cfdb668be7              []
# 3509  0x2f7383de70c972ef8c18565a9da023b08c110f2c              []
# 3510  0x04ad13a645748cee762f11e43386fe2a275885b4              []
# 3511  0x137faad0d13813ef8d4cbbb336f0e01066b2c9b4              []
# 3512  0x740426e58a10ac3b6724f753c8468288248137f9              []
#
#                                             logo_link  ... discord  \
# 3508   safe/files/scamDatabase/logo/60d50974c47c8.png  ...    None
# 3509   safe/files/scamDatabase/logo/60d508fa757bf.png  ...    None
# 3510  safe/files/scamDatabase/logo/60d50819f1be1.jpeg  ...    None
# 3511  safe/files/scamDatabase/logo/60d5003a01e5a.jpeg  ...    None
# 3512   safe/files/scamDatabase/logo/60df352021e17.png  ...    None
#
#      bug_bounty_program_link bug_bounty_program_company audit_code_conf  \
# 3508                    None                       None             NaN
# 3509                    None                       None             NaN
# 3510                    None                       None             NaN
# 3511                    None                       None             NaN
# 3512                    None                       None             NaN
#
#      is_verified_source_code is_public_team                       scam_type  \
# 3508                     NaN            NaN     {'id': 19, 'type': 'Other'}
# 3509                     NaN            NaN   {'id': 7, 'type': 'Honeypot'}
# 3510                     NaN            NaN     {'id': 19, 'type': 'Other'}
# 3511                     NaN            NaN     {'id': 19, 'type': 'Other'}
# 3512                     NaN            NaN  {'id': 5, 'type': 'Abandoned'}
#
#      network                                       scamNetworks  auditedBy
# 3508      {}  [{'networks_id': 56, 'scam_database_id': 78, '...         []
# 3509      {}  [{'networks_id': 56, 'scam_database_id': 77, '...         []
# 3510      {}  [{'networks_id': 56, 'scam_database_id': 76, '...         []
# 3511      {}  [{'networks_id': 56, 'scam_database_id': 72, '...         []
# 3512      {}  [{'networks_id': 56, 'scam_database_id': 55, '...         []
#
# [5 rows x 35 columns]

# %%
#finding out the shape of the data using "shape" variable: Output (rows, columns)
REKT_df.shape
# Out:
# (3513, 35)

# %%
#Printing all the columns present in data
REKT_df.columns
# Out:
# Index(['id', 'project_name', 'description', 'name_categories', 'token_name',
#        'proof_archive_link', 'technical_issue', 'token_address',
#        'token_addresses', 'logo_link', 'date', 'scam_updates', 'proof_link',
#        'website_link', 'webarchive_link', 'twitter_link', 'telegram_link',
#        'our_post_link', 'funds_lost', 'funds_returned', 'funds_by_chains',
#        'funds_recovered', 'active', 'git_hub', 'git_hub_contract_link',
#        'discord', 'bug_bounty_program_link', 'bug_bounty_program_company',
#        'audit_code_conf', 'is_verified_source_code', 'is_public_team',
#        'scam_type', 'network', 'scamNetworks', 'auditedBy'],
#       dtype='object')

# %%
#Checking for NaN values present in data
REKT_df.isna().sum() # also REKT_df.isnull().sum()
# Out:
# id                               0
# project_name                     0
# description                    285
# name_categories                  0
# token_name                     283
# proof_archive_link            2969
# technical_issue               3507
# token_address                  298
# token_addresses                  0
# logo_link                        0
# date                           923
# scam_updates                     0
# proof_link                     195
# website_link                  2471
# webarchive_link               3231
# twitter_link                  2749
# telegram_link                 2976
# our_post_link                 3473
# funds_lost                       0
# funds_returned                   0
# funds_by_chains                  0
# funds_recovered               3511
# active                           0
# git_hub                       3363
# git_hub_contract_link         3478
# discord                       3270
# bug_bounty_program_link       3500
# bug_bounty_program_company    3503
# audit_code_conf               3068
# is_verified_source_code       2478
# is_public_team                2478
# scam_type                        0
# network                          0
# scamNetworks                     0
# auditedBy                        0
# dtype: int64

# %%
# Removing spaces at beginning and at the end, if any, from column names
REKT_df.columns = REKT_df.columns.str.strip()

# %% [markdown]
# ## Dropping Variables That Do Not Assist in Analysis

# %% [markdown]
# Most of the variables that we shall drop from our 35 columns are links to external sites, such as web archive, discord, and github. Moreover, these variables contain more than 2900 NaN values out of a total observation count of 3076. However, the variable proof_link could be important if I decide to scrape text data from the linked article about a crypto attack. We shall also get rid of the technical_issue field because it only contains 4 non-NaN values and, more importantly, does not have any insightful use. Therefore, I find it sensible to entirely remove these fields, instead of getting rid of their existing NaN values, for EDA and modeling purposes.

# %%
REKT_df.drop(columns={'id','technical_issue', 'proof_archive_link', 'logo_link', 'website_link', 'twitter_link', 'our_post_link', 'telegram_link', 'git_hub', 'git_hub_contract_link', 'discord', 'bug_bounty_program_link', 'bug_bounty_program_company', 'audit_code_conf', 'funds_recovered', 'token_address', 'token_addresses', 'webarchive_link', 'funds_by_chains', 'scam_updates', 'active', 'proof_link', 'is_verified_source_code', 'is_public_team', 'network', 'auditedBy'}, inplace=True)

REKT_df.shape
# Out:
# (3513, 9)

# %%
REKT_df.columns
# Out:
# Index(['project_name', 'description', 'name_categories', 'token_name', 'date',
#        'funds_lost', 'funds_returned', 'scam_type', 'scamNetworks'],
#       dtype='object')

# %% [markdown]
# ## Variable Identification and Typecasting

# %%
# A closer look at the data types present in the data
REKT_df.dtypes
# Out:
# project_name       object
# description        object
# name_categories    object
# token_name         object
# date               object
# funds_lost          int64
# funds_returned      int64
# scam_type          object
# scamNetworks       object
# dtype: object

# %% [markdown]
# There are a lot of variables visible at once, so let's narrow this down by looking **at one datatype at once**. We will start with **int64** data type.

# %% [markdown]
# ### Integer Data Type

# %%
#Identifying variables with integer datatype
REKT_df.dtypes[REKT_df.dtypes == 'int64']
# Out:
# funds_lost        int64
# funds_returned    int64
# dtype: object

# %% [markdown]
# ### Object Data Type

# %%
#Identifying variables with object datatype
REKT_df.dtypes[REKT_df.dtypes == 'object']
# Out:
# project_name       object
# description        object
# name_categories    object
# token_name         object
# date               object
# scam_type          object
# scamNetworks       object
# dtype: object

# %% [markdown]
# *    **Variables like 'date', 'funds_lost', and 'funds_returned' are of type object**. This means that **Pandas was not able to recognise the datatype** of these four variables. Therefore, we shall convert these aforementioned object data type variables to their respective datatype

# %%
REKT_df['funds_lost'].head(10)
# Out:
# 0    40000000000
# 1     3600000000
# 2     3360000000
# 3     2900000000
# 4     2800000000
# 5     2000000000
# 6     2000000000
# 7     1500000000
# 8     1190000000
# 9     1000000000
# Name: funds_lost, dtype: int64

# %%
REKT_df['funds_returned'].head(10)
# Out:
# 0             0
# 1             0
# 2    3360000000
# 3             0
# 4             0
# 5             0
# 6      56000000
# 7             0
# 8             0
# 9             0
# Name: funds_returned, dtype: int64

# %%
#Converting the object data type variables to their respective datatype
REKT_df['funds_lost'] = REKT_df['funds_lost'].astype('float64')
REKT_df['funds_returned'] = REKT_df['funds_returned'].astype('float64')
REKT_df['date'] = pd.to_datetime(REKT_df['date'])

# %% [markdown]
# *    We will further investigate the datatime datatype and extract more information from it.

# %%
REKT_df.dtypes
# Out:
# project_name               object
# description                object
# name_categories            object
# token_name                 object
# date               datetime64[ns]
# funds_lost                float64
# funds_returned            float64
# scam_type                  object
# scamNetworks               object
# dtype: object

# %% [markdown]
# ### Float Data Type

# %%
# Identifying variables with float datatype
REKT_df.dtypes[REKT_df.dtypes == 'float64']
# Out:
# funds_lost        float64
# funds_returned    float64
# dtype: object

# %% [markdown]
# ***The funds variables should be float types.***

# %%
REKT_df.head()
# Out:
#     project_name                                        description  \
# 0  Terra Classic  <p><strong>Quick Summary</strong></p><p>A comp...
# 1      Africrypt  <p><strong>Quick Summary</strong></p><p>Ameer ...
# 2      Silk Road  <p><strong>Quick Summary</strong></p><p>Silk R...
# 3      PlusToken  <p><strong>Quick Summary</strong></p><p>The pe...
# 4        Genesis  <p><strong>Quick Summary</strong></p><p>Genesi...
#
#               name_categories  token_name       date    funds_lost  \
# 0                  Stablecoin  LUNC, USTC 2022-05-08  4.000000e+10
# 1                        CeFi        None 2021-06-23  3.600000e+09
# 2                       Other        None 2012-09-19  3.360000e+09
# 3                        CeFi        None 2019-12-16  2.900000e+09
# 4  CeFi,Borrowing and Lending        None 2022-11-21  2.800000e+09
#
#    funds_returned                      scam_type  \
# 0    0.000000e+00    {'id': 19, 'type': 'Other'}
# 1    0.000000e+00  {'id': 10, 'type': 'Rugpull'}
# 2    3.360000e+09    {'id': 19, 'type': 'Other'}
# 3    0.000000e+00  {'id': 10, 'type': 'Rugpull'}
# 4    0.000000e+00    {'id': 18, 'type': 'Other'}
#
#                                         scamNetworks
# 0  [{'networks_id': 1003, 'scam_database_id': 305...
# 1  [{'networks_id': 1666600003, 'scam_database_id...
# 2  [{'networks_id': 1666600003, 'scam_database_id...
# 3  [{'networks_id': 1666600003, 'scam_database_id...
# 4  [{'networks_id': 1666600003, 'scam_database_id...

# %% [markdown]
# ### datetime Data Type

# %% [markdown]
# *    ***We shall now extract important time-based features for better EDA experience***

# %%
# create time based features for pickup_datetime 
REKT_df['month_of_attack'] = REKT_df.date.dt.month
REKT_df['day_of_week_of_attack'] = REKT_df.date.dt.dayofweek
REKT_df['day_of_year_of_attack'] = REKT_df.date.dt.dayofyear

# %%
REKT_df.head()
# Out:
#     project_name                                        description  \
# 0  Terra Classic  <p><strong>Quick Summary</strong></p><p>A comp...
# 1      Africrypt  <p><strong>Quick Summary</strong></p><p>Ameer ...
# 2      Silk Road  <p><strong>Quick Summary</strong></p><p>Silk R...
# 3      PlusToken  <p><strong>Quick Summary</strong></p><p>The pe...
# 4        Genesis  <p><strong>Quick Summary</strong></p><p>Genesi...
#
#               name_categories  token_name       date    funds_lost  \
# 0                  Stablecoin  LUNC, USTC 2022-05-08  4.000000e+10
# 1                        CeFi        None 2021-06-23  3.600000e+09
# 2                       Other        None 2012-09-19  3.360000e+09
# 3                        CeFi        None 2019-12-16  2.900000e+09
# 4  CeFi,Borrowing and Lending        None 2022-11-21  2.800000e+09
#
#    funds_returned                      scam_type  \
# 0    0.000000e+00    {'id': 19, 'type': 'Other'}
# 1    0.000000e+00  {'id': 10, 'type': 'Rugpull'}
# 2    3.360000e+09    {'id': 19, 'type': 'Other'}
# 3    0.000000e+00  {'id': 10, 'type': 'Rugpull'}
# 4    0.000000e+00    {'id': 18, 'type': 'Other'}
#
#                                         scamNetworks  month_of_attack  \
# 0  [{'networks_id': 1003, 'scam_database_id': 305...              5.0
# 1  [{'networks_id': 1666600003, 'scam_database_id...              6.0
# 2  [{'networks_id': 1666600003, 'scam_database_id...              9.0
# 3  [{'networks_id': 1666600003, 'scam_database_id...             12.0
# 4  [{'networks_id': 1666600003, 'scam_database_id...             11.0
#
#    day_of_week_of_attack  day_of_year_of_attack
# 0                    6.0                  128.0
# 1                    2.0                  174.0
# 2                    2.0                  263.0
# 3                    0.0                  350.0
# 4                    0.0                  325.0

# %%
REKT_df.tail()
# Out:
#            project_name                                        description  \
# 3158               Cezo  <p><span data-sheets-userformat='{"2":15165,"3...
# 3159         VikingSwap                                               None
# 3160     PabloEscobarFi                                               None
# 3161  Crocoswap finance  <p><span data-sheets-userformat='{"2":15165,"3...
# 3162          Chef Swap                                               None
#
#      name_categories token_name       date  funds_lost  funds_returned  \
# 3158            None  CEZ CEZV2        NaT         0.0             0.0
# 3159            None     VIKING 2021-03-07         0.0             0.0
# 3160            None       ESCO 2021-03-10         0.0             0.0
# 3161            None      CROCO 2021-03-14         0.0             0.0
# 3162            None       CHEF 2021-03-12         0.0             0.0
#
#                            scam_type  \
# 3158     {'id': 19, 'type': 'Other'}
# 3159  {'id': 5, 'type': 'Abandoned'}
# 3160     {'id': 19, 'type': 'Other'}
# 3161     {'id': 19, 'type': 'Other'}
# 3162     {'id': 19, 'type': 'Other'}
#
#                                            scamNetworks  month_of_attack  \
# 3158  [{'networks_id': 1, 'scam_database_id': 98, 'n...              NaN
# 3159  [{'networks_id': 56, 'scam_database_id': 97, '...              3.0
# 3160  [{'networks_id': 56, 'scam_database_id': 93, '...              3.0
# 3161  [{'networks_id': 56, 'scam_database_id': 81, '...              3.0
# 3162  [{'networks_id': 56, 'scam_database_id': 80, '...              3.0
#
#       day_of_week_of_attack  day_of_year_of_attack
# 3158                    NaN                    NaN
# 3159                    6.0                   66.0
# 3160                    2.0                   69.0
# 3161                    6.0                   73.0
# 3162                    4.0                   71.0

# %%
REKT_df.dtypes
# Out:
# project_name                     object
# description                      object
# name_categories                  object
# token_name                       object
# date                     datetime64[ns]
# funds_lost                      float64
# funds_returned                  float64
# scam_type                        object
# scamNetworks                     object
# month_of_attack                 float64
# day_of_week_of_attack           float64
# day_of_year_of_attack           float64
# dtype: object

# %%
REKT_df.describe()
# Out:
#          funds_lost  funds_returned  month_of_attack  day_of_week_of_attack  \
# count  3.163000e+03    3.163000e+03      1290.000000            1290.000000
# mean   2.357216e+07    1.880971e+06         7.529457               2.591473
# std    7.239666e+08    6.204393e+07         3.118973               1.965905
# min    0.000000e+00    0.000000e+00         1.000000               0.000000
# 25%    0.000000e+00    0.000000e+00         6.000000               1.000000
# 50%    0.000000e+00    0.000000e+00         8.000000               3.000000
# 75%    1.047700e+04    0.000000e+00        10.000000               4.000000
# max    4.000000e+10    3.360000e+09        12.000000               6.000000
#
#        day_of_year_of_attack
# count            1290.000000
# mean              213.958915
# std                95.596364
# min                 1.000000
# 25%               154.000000
# 50%               242.000000
# 75%               277.000000
# max               366.000000

# %% [markdown]
# ### Removing HTML Tags from Description variable

# %%
REKT_df.loc[REKT_df['description'].isnull(), 'funds_lost']
# Out:
# 104     20000000.0
# 894            0.0
# 895            0.0
# 899            0.0
# 900            0.0
#            ...
# 3149           0.0
# 3151           0.0
# 3159           0.0
# 3160           0.0
# 3162           0.0
# Name: funds_lost, Length: 283, dtype: float64

# %%
REKT_df.loc[REKT_df['description'].isnull()]
# Out:
#         project_name description name_categories token_name       date  \
# 104    Yfdex.Finance        None            CeFi      YFDEX 2020-09-09
# 894          Mystery        None            None        MST 2021-10-18
# 895   FlokiFarmToken        None            None        FLK 2021-10-18
# 899    AwakenedToken        None            None        AWA 2021-10-11
# 900    LionKingToken        None            None        LKS 2021-10-11
# ...              ...         ...             ...        ...        ...
# 3149        Microbit        None            None        MBT        NaT
# 3151           W3RLD        None            None      W3RLD        NaT
# 3159      VikingSwap        None            None     VIKING 2021-03-07
# 3160  PabloEscobarFi        None            None       ESCO 2021-03-10
# 3162       Chef Swap        None            None       CHEF 2021-03-12
#
#       funds_lost  funds_returned                       scam_type  \
# 104   20000000.0             0.0   {'id': 10, 'type': 'Rugpull'}
# 894          0.0             0.0   {'id': 10, 'type': 'Rugpull'}
# 895          0.0             0.0   {'id': 10, 'type': 'Rugpull'}
# 899          0.0             0.0   {'id': 10, 'type': 'Rugpull'}
# 900          0.0             0.0   {'id': 10, 'type': 'Rugpull'}
# ...          ...             ...                             ...
# 3149         0.0             0.0     {'id': 19, 'type': 'Other'}
# 3151         0.0             0.0     {'id': 19, 'type': 'Other'}
# 3159         0.0             0.0  {'id': 5, 'type': 'Abandoned'}
# 3160         0.0             0.0     {'id': 19, 'type': 'Other'}
# 3162         0.0             0.0     {'id': 19, 'type': 'Other'}
#
#                                            scamNetworks  month_of_attack  \
# 104   [{'networks_id': 1, 'scam_database_id': 42, 'n...              9.0
# 894   [{'networks_id': 250, 'scam_database_id': 2678...             10.0
# 895   [{'networks_id': 250, 'scam_database_id': 2677...             10.0
# 899   [{'networks_id': 250, 'scam_database_id': 2673...             10.0
# 900   [{'networks_id': 250, 'scam_database_id': 2672...             10.0
# ...                                                 ...              ...
# 3149  [{'networks_id': 1, 'scam_database_id': 169, '...              NaN
# 3151  [{'networks_id': 1, 'scam_database_id': 151, '...              NaN
# 3159  [{'networks_id': 56, 'scam_database_id': 97, '...              3.0
# 3160  [{'networks_id': 56, 'scam_database_id': 93, '...              3.0
# 3162  [{'networks_id': 56, 'scam_database_id': 80, '...              3.0
#
#       day_of_week_of_attack  day_of_year_of_attack
# 104                     2.0                  253.0
# 894                     0.0                  291.0
# 895                     0.0                  291.0
# 899                     0.0                  284.0
# 900                     0.0                  284.0
# ...                     ...                    ...
# 3149                    NaN                    NaN
# 3151                    NaN                    NaN
# 3159                    6.0                   66.0
# 3160                    2.0                   69.0
# 3162                    4.0                   71.0
#
# [283 rows x 12 columns]

# %%
REKT_df.loc[REKT_df['funds_lost']==20000000.0]
# Out:
#       project_name                                        description  \
# 103          Auros  <p dir="ltr" style="line-height:1.38;backgroun...
# 104  Yfdex.Finance                                               None
#
#     name_categories token_name       date  funds_lost  funds_returned  \
# 103            CeFi       None 2022-12-20  20000000.0             0.0
# 104            CeFi      YFDEX 2020-09-09  20000000.0             0.0
#
#                          scam_type  \
# 103    {'id': 18, 'type': 'Other'}
# 104  {'id': 10, 'type': 'Rugpull'}
#
#                                           scamNetworks  month_of_attack  \
# 103  [{'networks_id': 1666600003, 'scam_database_id...             12.0
# 104  [{'networks_id': 1, 'scam_database_id': 42, 'n...              9.0
#
#      day_of_week_of_attack  day_of_year_of_attack
# 103                    1.0                  354.0
# 104                    2.0                  253.0

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(REKT_df.iloc[0,1]) # testing performance of the function on description column, first row

print(soup.get_text())
# Out:
# Quick SummaryA complex mixture of events and market dynamics cost the implosion of the $40b Terra (Classic) Network. Details of the ExploitThe Terra Luna Network was focused on its two native coins $LUNC and $USTC. $USTC was the algorithmic Stablecoin that was supposed to hold the peg to 1$ and $LUNC functioned as the satellite asset that absorbed $USTC’s volatility. This was achieved through a mint and burn functionality as well as by arbitrage which the former function inherently enabled.$USTC rose to prominence in rapid fashion even surpassing $DAI in market cap. The Luna Foundation Group decided to start a new Curve4pool with $FRAX, $USTC, $USDC and $USDT as assets, excluding $DAI in an attempt to starve the most used StableCoin pool used by institutions the Curve3pool on the Ethereum network.The migration of $USTC from the Curve3pool is the event that started the bankrun. In early May, the Luna Foundation Guard withdrew 250 million $USTC from the Curve3pool in preparation for the Curve4pool. Simultaneously, a handful of whales withdrew sizeable amounts from the anchor protocol, a crypto savings bank. The biggest wallet withdrew 347 million $USTC in total and bridged funds to the Curve3pool in order to swap for other assets. This movement of funds created an imbalance between $USTC and other Stablecoins in the pool, resulting in devaluation of $USTC on exchanges.As a result of the tokenomics of $USTC and $LUNC the firesale of $USTC resulted in uncontrollable minting of the $LUNC token and a rapid fall in valuation. Additionally, the Terra network went down due to overload in transaction as market participants were panicking and trying to answer margin calls within the Anchor protocol. Eventually massive liquidations of collateral in the Anchor protocol would be incurred by investors.Block Data ReferenceWhale Addresses:https://etherscan.io/address/0x8d47f08ebc5554504742f547eb721a43d4947d0ahttps://etherscan.io/address/0x4b5e60cb1cd6c5e67af5e6cf63229d1614bb781chttps://etherscan.io/address/0x1df8ea15bb725e110118f031e8e71b91abaa2a06https://etherscan.io/address/0xeb5425e650b04e49e5e8b62fbf1c3f60df01f232https://etherscan.io/address/0x41339d9825963515e5705df8d3b0ea98105ebb1chttps://etherscan.io/address/0x68963dc7c28a36fcacb0b39ac2d807b0329b9c69https://etherscan.io/address/0x9f705ff1da72ed334f0e80f90aae5644f5cd7784

# %%
from bs4 import BeautifulSoup

# imputing empty strings in all missing vals of description variable instead of dropping those rows

#REKT_df_descr_clean = REKT_df.loc[REKT_df['description'].isnull(), 'funds_lost']
REKT_df['description'].fillna("", inplace=True)
#REKT_df_clean = REKT_df.loc[(REKT_df['description'].notnull() & REKT_df['funds_lost']==20000000.0)]

# An observation that has a high funds lost value but no description must be preserved. So, we convert all of description's missing value to empty string to avoid bs4 errors

# running bs4 on description variable
for index in range(REKT_df.shape[0]):
   soup = BeautifulSoup(REKT_df.iloc[index,1])
   REKT_df.iloc[index,1] = soup.get_text()

# %%
REKT_df.head()
# Out:
#     project_name                                        description  \
# 0  Terra Classic  Quick SummaryA complex mixture of events and m...
# 1      Africrypt  Quick SummaryAmeer and Raees Cajee, the exchan...
# 2      Silk Road  Quick SummarySilk Road dark web market was exp...
# 3      PlusToken  Quick SummaryThe perpetrators of one of the la...
# 4        Genesis  Quick SummaryGenesis crypto trading platform h...
#
#               name_categories  token_name       date    funds_lost  \
# 0                  Stablecoin  LUNC, USTC 2022-05-08  4.000000e+10
# 1                        CeFi        None 2021-06-23  3.600000e+09
# 2                       Other        None 2012-09-19  3.360000e+09
# 3                        CeFi        None 2019-12-16  2.900000e+09
# 4  CeFi,Borrowing and Lending        None 2022-11-21  2.800000e+09
#
#    funds_returned                      scam_type  \
# 0    0.000000e+00    {'id': 19, 'type': 'Other'}
# 1    0.000000e+00  {'id': 10, 'type': 'Rugpull'}
# 2    3.360000e+09    {'id': 19, 'type': 'Other'}
# 3    0.000000e+00  {'id': 10, 'type': 'Rugpull'}
# 4    0.000000e+00    {'id': 18, 'type': 'Other'}
#
#                                         scamNetworks  month_of_attack  \
# 0  [{'networks_id': 1003, 'scam_database_id': 305...              5.0
# 1  [{'networks_id': 1666600003, 'scam_database_id...              6.0
# 2  [{'networks_id': 1666600003, 'scam_database_id...              9.0
# 3  [{'networks_id': 1666600003, 'scam_database_id...             12.0
# 4  [{'networks_id': 1666600003, 'scam_database_id...             11.0
#
#    day_of_week_of_attack  day_of_year_of_attack
# 0                    6.0                  128.0
# 1                    2.0                  174.0
# 2                    2.0                  263.0
# 3                    0.0                  350.0
# 4                    0.0                  325.0

# %%
# removing "Quick Summary" in the beginning of valid description values

REKT_df['description'] = REKT_df['description'].apply(lambda x: x.replace("Quick Summary", ""))

# %%
REKT_df.iloc[0:10,1]
# Out:
# 0    A complex mixture of events and market dynamic...
# 1    Ameer and Raees Cajee, the exchange's founders...
# 2    Silk Road dark web market was exploited on 19 ...
# 3    The perpetrators of one of the largest digital...
# 4    Genesis crypto trading platform has 2,800,000,...
# 5    Thodex a turkish crypto exchange went down wit...
# 6    BitConnect was a Ponzi Scheme that managed to ...
# 7    Finiko company which offers Bitcoin investment...
# 8    Celcius Network filed Chapter 11 bankruptcy af...
# 9    Voyager crypto platform filed for bankruptcy, ...
# Name: description, dtype: object

# %%
REKT_df.shape
# Out:
# (3163, 12)

# %% [markdown]
# ### Extracting Network Name (eg Ethereum, Binance etc) from scamNetworks variable

# %%
import jmespath # testing performance of jmespath on scamNetworks column, first row
tmp = jmespath.search('[].networks.name', REKT_df.scamNetworks[0])
#REKT_df.scamNetworks[1]['networks']
print(tmp)
# Out:
# ['Terra Classic']

# %%
# using for loop and jmespath to extract network name
clean_network=[]

for i in range(len(REKT_df)):
  clean_network.append(jmespath.search('[].networks.name', REKT_df.scamNetworks[i]))

REKT_df['scamNetworks']=clean_network
REKT_df['scamNetworks'].head()
# Out:
# 0    [Terra Classic]
# 1      [Centralized]
# 2      [Centralized]
# 3      [Centralized]
# 4      [Centralized]
# Name: scamNetworks, dtype: object

# %%
REKT_df
# Out:
#            project_name                                        description  \
# 0         Terra Classic  A complex mixture of events and market dynamic...
# 1             Africrypt  Ameer and Raees Cajee, the exchange's founders...
# 2             Silk Road  Silk Road dark web market was exploited on 19 ...
# 3             PlusToken  The perpetrators of one of the largest digital...
# 4               Genesis  Genesis crypto trading platform has 2,800,000,...
# ...                 ...                                                ...
# 3158               Cezo  The team was dumping tokens into the market. T...
# 3159         VikingSwap
# 3160     PabloEscobarFi
# 3161  Crocoswap finance  The project team switched to another MasterChe...
# 3162          Chef Swap
#
#                  name_categories  token_name       date    funds_lost  \
# 0                     Stablecoin  LUNC, USTC 2022-05-08  4.000000e+10
# 1                           CeFi        None 2021-06-23  3.600000e+09
# 2                          Other        None 2012-09-19  3.360000e+09
# 3                           CeFi        None 2019-12-16  2.900000e+09
# 4     CeFi,Borrowing and Lending        None 2022-11-21  2.800000e+09
# ...                          ...         ...        ...           ...
# 3158                        None   CEZ CEZV2        NaT  0.000000e+00
# 3159                        None      VIKING 2021-03-07  0.000000e+00
# 3160                        None        ESCO 2021-03-10  0.000000e+00
# 3161                        None       CROCO 2021-03-14  0.000000e+00
# 3162                        None        CHEF 2021-03-12  0.000000e+00
#
#       funds_returned                       scam_type     scamNetworks  \
# 0       0.000000e+00     {'id': 19, 'type': 'Other'}  [Terra Classic]
# 1       0.000000e+00   {'id': 10, 'type': 'Rugpull'}    [Centralized]
# 2       3.360000e+09     {'id': 19, 'type': 'Other'}    [Centralized]
# 3       0.000000e+00   {'id': 10, 'type': 'Rugpull'}    [Centralized]
# 4       0.000000e+00     {'id': 18, 'type': 'Other'}    [Centralized]
# ...              ...                             ...              ...
# 3158    0.000000e+00     {'id': 19, 'type': 'Other'}       [Ethereum]
# 3159    0.000000e+00  {'id': 5, 'type': 'Abandoned'}        [Binance]
# 3160    0.000000e+00     {'id': 19, 'type': 'Other'}        [Binance]
# 3161    0.000000e+00     {'id': 19, 'type': 'Other'}        [Binance]
# 3162    0.000000e+00     {'id': 19, 'type': 'Other'}        [Binance]
#
#       month_of_attack  day_of_week_of_attack  day_of_year_of_attack
# 0                 5.0                    6.0                  128.0
# 1                 6.0                    2.0                  174.0
# 2                 9.0                    2.0                  263.0
# 3                12.0                    0.0                  350.0
# 4                11.0                    0.0                  325.0
# ...               ...                    ...                    ...
# 3158              NaN                    NaN                    NaN
# 3159              3.0                    6.0                   66.0
# 3160              3.0                    2.0                   69.0
# 3161              3.0                    6.0                   73.0
# 3162              3.0                    4.0                   71.0
#
# [3163 rows x 12 columns]

# %%
# Exporting full DF as CSV (missing vals present in other columns except Description)

REKT_df.to_csv("../Data/REKT_Database_Clean_Python.csv")

# %% [markdown]
# *   Now we are done breaking down the date of attack datetime variable into granular forms, as seen above, which will **help us better analyze crypto crimes.** We are also done with the Variable identification and typecasting process and will now start the Univariate Analysis portion of the EDA, followed by Bivariate Analysis, and, lastly, Multivariate Analysis.
